# %% [markdown]
# # Bounding box detection - Racoon data
#
#
# ## Data files
# - images_racoon.rar: contain images of racoons
# - train_labels.cv: contains coordinates for bounding box for every image

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Import the necessary libraries

# %%
# %tensorflow_version 2.x

import csv
import os
import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.utils import Sequence
from tensorflow.keras.backend import epsilon
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback

# %% [markdown]
# ### Change directory

# %%
project_path = '/content/drive/My Drive/Colab Notebooks/Lab/R9'

# %%
os.chdir(project_path)

# %%
# Check current working directory.
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Lab/R9'

# %% [markdown]
# ### Load the training data from train.csv file

# %%
train_labels_df = pd.read_csv('train_labels.csv')

# %% [markdown]
# ### Print the shape of the train dataset

# %%
train_labels_df.shape
# Out:
# (173, 8)

# %%
train_labels_df.head(8)
# Out:
#           filename  width  height    class  xmin  ymin  xmax  ymax
# 0   raccoon-17.jpg    259     194  raccoon    95    60   167   118
# 1   raccoon-11.jpg    660     432  raccoon     3     1   461   431
# 2   raccoon-63.jpg    600     400  raccoon    74   107   280   290
# 3   raccoon-63.jpg    600     400  raccoon   227    93   403   298
# 4   raccoon-60.jpg    273     185  raccoon    58    33   197   127
# 5   raccoon-69.jpg    205     246  raccoon    12    11   188   240
# 6  raccoon-180.jpg    600     400  raccoon   119    21   368   399
# 7  raccoon-200.jpg    261     193  raccoon   107    10   249   166

# %%
train_labels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 8 columns):
# filename    173 non-null object
# width       173 non-null int64
# height      173 non-null int64
# class       173 non-null object
# xmin        173 non-null int64
# ymin        173 non-null int64
# xmax        173 non-null int64
# ymax        173 non-null int64
# dtypes: int64(6), object(2)
# memory usage: 10.9+ KB

# %%
train_labels_df.isnull().sum()
# Out:
# filename    0
# width       0
# height      0
# class       0
# xmin        0
# ymin        0
# xmax        0
# ymax        0
# dtype: int64

# %%
train_labels_df['class'].value_counts()
# Out:
# raccoon    173
# Name: class, dtype: int64

# %% [markdown]
# ### Declare a variable IMAGE_SIZE = 128 as we will be using MobileNet which will be taking Input shape as 128 * 128

# %%
IMAGE_SIZE = 128
TRAIN_CSV = 'train_labels.csv'
ALPHA = 1.0

# %% [markdown]
# ### With the help of csv.reader write a for loop which can load the train.csv file and store the path, width, height, x0,y0,x1,y1 in induvidual variables. <br>
# 1. Create a list variable known as 'path' which has all the path for all the training images
# 2. Create an array 'coords' which has the resized coordinates of the bounding box for the training images
#
# <u>Note:</u> All the training images should be downsampled to 128 * 128 as it is the input shape of MobileNet (which we will be using for Object detection). Hence the corresponding coordinates of the bounding boxes should be changed to match the image dimension of 128 * 128

# %%
with open(TRAIN_CSV, 'r') as csvfile:
    paths = []
    coords = np.zeros((sum(1 for line in csvfile), 4))
    reader = csv.reader(csvfile, delimiter=',')
    csvfile.seek(0)
    for col, row in enumerate(reader):
        if(col != 0):
            for i, r in enumerate(row[0:8]): # Parse row with seven entities
                if(i == 0 or i == 3):
                    pass
                else:
                    row[i] = int(r)
            path, image_height, image_width, _, x0, y0, x1, y1 = row
            path = './images/' + path 
            coords[col, 0] = x0 * IMAGE_SIZE / image_width # Normalize bounding box by image size
            coords[col, 1] = y0 * IMAGE_SIZE / image_height # Normalize bounding box by image size
            coords[col, 2] = (x1 - x0) * IMAGE_SIZE / image_width # Normalize bounding box by image size
            coords[col, 3] = (y1 - y0) * IMAGE_SIZE / image_height
            paths.append(path)

# %% [markdown]
# ### Write a for loop which can load all the training images into a variable 'batch_images' using the paths from the 'paths' variable
# <u>Note:</u> Convert the image to RGB scale as the MobileNet accepts 3 channels as inputs

# %%
# !pip install rarFile

# %%
# from rarfile import RarFile

# with RarFile('images_racoon.rar', 'r') as r:
#  r.extractall()

# %%
len(paths)
# Out:
# 173

# %%
batch_images = np.zeros((len(paths), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
for i, f in enumerate(paths):
    img = Image.open(f) # Read image
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE)) # Resize image
    img = img.convert('RGB')
    batch_images[i] = preprocess_input(np.array(img, dtype=np.float32))

# %% [markdown]
# ### Import MobileNet and load MobileNet into a variable named 'model' which takes input shape of 128 * 128 * 3. Freeze all the layers. Add convolution and reshape layers at the end to ensure the output is 4 coordinates

# %%
model = MobileNet(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False, alpha=ALPHA) # Load pre-trained mobilenet
# Do not include classification (top) layer

# to freeze layers, except the new top layer, of course, which will be added below
for layer in model.layers:
    layer.trainable = False

# Add new top layer which is a conv layer of the same size as the previous layer so that only 4 coords of BBox can be output
x = model.layers[-1].output
x = Conv2D(4, kernel_size=4, name="coords")(x)
# In the line above kernel size should be 3 for img size 96, 4 for img size 128, 5 for img size 160 etc.
x = Reshape((4,))(x) # These are the 4 predicted coordinates of one BBox

model = Model(inputs=model.input, outputs=x)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_128_tf_no_top.h5
# 17227776/17225924 [==============================] - 1s 0us/step

# %% [markdown]
# ### Define a custom loss function IoU which calculates Intersection Over Union

# %%
gt = coords

# %%
def loss(gt,pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,0])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,1])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

#     Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use epsilon to prevent division by zero
    iou = np.round(intersections / (unions + epsilon()), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.py_function(loss, [y_true, y_pred], tf.float32)
    return iou

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 129, 129, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 64, 64, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 64, 64, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 64, 64, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 64, 64, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 64, 64, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 64, 64, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 64, 64, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 64, 64, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 65, 65, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 32, 32, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 32, 32, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 32, 32, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 32, 32, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 32, 32, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 32, 32, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 33, 33, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 16, 16, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 16, 16, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 16, 16, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 16, 16, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 17, 17, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 8, 8, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 8, 8, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 9, 9, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 4, 4, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 4, 4, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 4, 4, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 4, 4, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 4, 4, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 4, 4, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 4, 4, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 4, 4, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 4, 4, 1024)        0
# _________________________________________________________________
# coords (Conv2D)              (None, 1, 1, 4)           65540
# _________________________________________________________________
# reshape (Reshape)            (None, 4)                 0
# =================================================================
# Total params: 3,294,404
# Trainable params: 65,540
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %% [markdown]
# ### Write model.compile function & model.fit function with: <br>
# 1. Optimizer = Adam, Loss = 'mse' and metrics = IoU
# 2. Epochs = 30, batch_size = 32, verbose = 1

# %%
model.compile(optimizer='adam', loss='mse', metrics=[IoU]) # Regression loss is MSE

# %%
len(gt[1:])
# Out:
# 173

# %%
model.fit(batch_images,gt[1:],
            epochs=30,batch_size = 32,
            verbose=1)
# Out:
# Train on 173 samples
# Epoch 1/30
# 173/173 [==============================] - 8s 48ms/sample - loss: 3217.0473 - IoU: 0.0967
# Epoch 2/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 993.8876 - IoU: 0.3768
# Epoch 3/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 938.4639 - IoU: 0.4291
# Epoch 4/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 885.7808 - IoU: 0.4574
# Epoch 5/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 595.7912 - IoU: 0.5101
# Epoch 6/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 490.8449 - IoU: 0.5239
# Epoch 7/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 433.4043 - IoU: 0.5477
# Epoch 8/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 361.7899 - IoU: 0.5860
# Epoch 9/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 312.5004 - IoU: 0.6110
# Epoch 10/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 277.3106 - IoU: 0.6440
# Epoch 11/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 242.6070 - IoU: 0.6581
# Epoch 12/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 207.5333 - IoU: 0.6777
# Epoch 13/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 195.0946 - IoU: 0.6891
# Epoch 14/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 179.0586 - IoU: 0.7081
# Epoch 15/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 167.5420 - IoU: 0.7097
# Epoch 16/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 163.1003 - IoU: 0.7187
# Epoch 17/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 147.7516 - IoU: 0.7095
# Epoch 18/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 137.6660 - IoU: 0.7238
# Epoch 19/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 134.6352 - IoU: 0.7366
# Epoch 20/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 126.2502 - IoU: 0.7499
# Epoch 21/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 116.9210 - IoU: 0.7519
# Epoch 22/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 107.2544 - IoU: 0.7650
# Epoch 23/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 109.2851 - IoU: 0.7773
# Epoch 24/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 95.7243 - IoU: 0.7819
# Epoch 25/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 91.0480 - IoU: 0.7871
# Epoch 26/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 94.0065 - IoU: 0.7905
# Epoch 27/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 94.9025 - IoU: 0.7827
# Epoch 28/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 101.2928 - IoU: 0.7736
# Epoch 29/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 88.5970 - IoU: 0.7999
# Epoch 30/30
# 173/173 [==============================] - 0s 2ms/sample - loss: 83.1874 - IoU: 0.8023

# %% [markdown]
# ### Pick a test image from the given data

# %%
# Pick a test image, run model, show image, and show predicted bounding box overlaid on the image
import cv2
filename = './images/images/raccoon-180.jpg'
unscaled = cv2.imread(filename) # Original image for display

# %% [markdown]
# ### Resize the image to 128 * 128 and preprocess the image for the MobileNet model

# %%
image_height, image_width, _ = unscaled.shape
image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE)) # Rescaled image to run the network
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

# %% [markdown]
# ### Predict the coordinates of the bounding box for the given test image

# %%
region = model.predict(x=np.array([feat_scaled]))[0] # Predict the BBox

# %% [markdown]
# ### Plot the test image using .imshow and draw a boundary box around the image with the coordinates obtained from the model

# %%
x0 = int(region[0] * image_width / IMAGE_SIZE) # Scale the BBox
y0 = int(region[1] * image_height / IMAGE_SIZE)

x1 = int((region[2]) * image_width / IMAGE_SIZE)
y1 = int((region[3]) * image_height / IMAGE_SIZE)


import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np


# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(unscaled)

# Create a Rectangle patch
rect = patches.Rectangle((x0, y0), (x1 - x0) , (y1 - y0) , linewidth=2, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %% [markdown]
# # Time Series Prediction using LSTM

# %% [markdown]
# ### Download Data
# Link: https://datamarket.com/data/set/2324/daily-minimum-temperatures-in-melbourne-australia-1981-1990#!ds=2324&display=line
#
# #### Description
# Daily minimum temperatures in Melbourne, Australia, 1981-1990
#
# Units: Degrees Celcius
#
# #### Steps before loading
# - Rename the column name with temprature values to "Temprature"
# - In the last, there is one extra row in the data, remove it by opening the file and save it again.
# - There are some values in Temprature column which have a "?" before them, they will give error, remove "?" before them and save the file
# - If you don't want to do these steps, just load the data file given by Great Learning.

# %% [markdown]
# #### Mount google drive

# %%
# Done at the top

# %% [markdown]
# #### Change your present working directory

# %%
# Done at the top

# %% [markdown]
# ### Load your data file

# %%
daily_temp_df = pd.read_csv('daily-minimum-temperatures-in-me.csv', index_col='Date')

# %% [markdown]
# #### Plot data

# %%
daily_temp_df_original = daily_temp_df.copy(deep=True)

# %%
daily_temp_df['Date'] = pd.to_datetime(daily_temp_df['Date'], errors='coerce')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20,5))
sns.lineplot(data=daily_temp_df)

# %% [markdown]
# #### Descibe your dataframe

# %%
daily_temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3650 entries, 1981-01-01 to 1990-12-31
# Data columns (total 1 columns):
# Temperature    3650 non-null float64
# dtypes: float64(1)
# memory usage: 57.0+ KB

# %%
daily_temp_df.describe()
# Out:
#        Temperature
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %% [markdown]
# #### Check for null values

# %%
daily_temp_df.isna().sum()
# Out:
# Temperature    0
# dtype: int64

# %% [markdown]
# #### Drop null values

# %%
daily_temp_df.dropna(axis=0, inplace=True)

# %% [markdown]
# #### Get the representation of the distribution of data in the form of histogram

# %%
sns.distplot(daily_temp_df['Temperature'])

# %% [markdown]
# #### Check the maximum and minimum values

# %%
# Scaled Data
print('Min\n', np.min(daily_temp_df))
print('\nMax\n', np.max(daily_temp_df))
# Out:
# Min
#  Temperature    0.0
# dtype: float64
#
# Max
#  Temperature    26.3
# dtype: float64

# %% [markdown]
# ### Normalize the data

# %%
#convert datatype to float 
daily_temp_df = daily_temp_df.astype('float32')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
#apply the sclaing to make values between 0 to 1
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(daily_temp_df)

# %% [markdown]
# #### Check the maximum and minimum values of scaled data

# %%
print('Min', np.min(scaled))
print('Max', np.max(scaled))
# Out:
# Min 0.0
# Max 1.0

# %% [markdown]
# #### Look into some of the scaled values

# %%
print(scaled[:10])
# Out:
# [[0.7870723 ]
#  [0.6806084 ]
#  [0.7148289 ]
#  [0.5551331 ]
#  [0.6007605 ]
#  [0.6007605 ]
#  [0.6007605 ]
#  [0.661597  ]
#  [0.82889736]
#  [0.7604563 ]]

# %% [markdown]
# ### Split data into Training and Testing

# %%
#Split the data into train and test based on time
train_size = int(len(scaled) * 0.70)
test_size = len(scaled - train_size)
train, test = scaled[0:train_size, :], scaled[train_size: len(scaled), :]

# %% [markdown]
# #### Print train and test size

# %%
print('train: {}\ntest: {}'.format(len(train), len(test)))
# Out:
# train: 2555
# test: 1095

# %% [markdown]
# ## Create the sequential data
# Map the temprature at a particular time t to the temprature at time t+n, where n is any number you define.
#
# For example: to map tempratures of consecutive days, use t+1, i.e. loop_back = 1

# %% [markdown]
# #### Define your function to create dataset

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]        
        dataX.append(a)        
        dataY.append(dataset[i + look_back, 0])        
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# #### Use function to get training and test set

# %%
look_back = 1
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
len(X_train)
# Out:
# 2554

# %% [markdown]
# #### Transform the prepared train and test input data into the expected structure using numpy.reshape()

# %%
#samples, time_steps, features
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_train.shape)
print(X_test.shape)
# Out:
# (2554, 1, 1)
# (1094, 1, 1)

# %% [markdown]
# ## Define Model

# %% [markdown]
# ### Define sequntial model, add LSTM layer and compile the model

# %%
from tensorflow.keras.layers import LSTM, Dense

# %%
#The network has a visible layer with 1 input, a hidden layer with 4 LSTM blocks or neurons, and an output layer that makes a single value prediction. The default sigmoid activation function is used for the LSTM blocks. The network is trained for 100 epochs and a batch size of 1 is used.
#create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# ### Summarize your model

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (1, 4)                    96
# _________________________________________________________________
# dense_2 (Dense)              (1, 1)                    5
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
model.fit(X_train, y_train, epochs=200, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Train on 2554 samples
# Epoch 1/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0154
# Epoch 2/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0105
# Epoch 3/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0103
# Epoch 4/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0103
# Epoch 5/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 6/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0103
# Epoch 7/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 8/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0103
# Epoch 9/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 10/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0103
# Epoch 11/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 12/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 13/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 14/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 15/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 16/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 17/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 18/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 19/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 20/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 21/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 22/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 23/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 24/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 25/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 26/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 27/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 28/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 29/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 30/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 31/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 32/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 33/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 34/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 35/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 36/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 37/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 38/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 39/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 40/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 41/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 42/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 43/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 44/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 45/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 46/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 47/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 48/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 49/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 50/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 51/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 52/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 53/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 54/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 55/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 56/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 57/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 58/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 59/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 60/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 61/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 62/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 63/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 64/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 65/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 66/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 67/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 68/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 69/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 70/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 71/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 72/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 73/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 74/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 75/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 76/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 77/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 78/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 79/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 80/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 81/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 82/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0102
# Epoch 83/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 84/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 85/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 86/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 87/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 88/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 89/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 90/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 91/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 92/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 93/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 94/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 95/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 96/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 97/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 98/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 99/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 100/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 101/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 102/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 103/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 104/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 105/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 106/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 107/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 108/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 109/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 110/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 111/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 112/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 113/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 114/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 115/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 116/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 117/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 118/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 119/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 120/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 121/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 122/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 123/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 124/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 125/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 126/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 127/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 128/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 129/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 130/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 131/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 132/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 133/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 134/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 135/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 136/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 137/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 138/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 139/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 140/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 141/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 142/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 143/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 144/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 145/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 146/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 147/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 148/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 149/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 150/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 151/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 152/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 153/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 154/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0100
# Epoch 155/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 156/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 157/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 158/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 159/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 160/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 161/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 162/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 163/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0100
# Epoch 164/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0100
# Epoch 165/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 166/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 167/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 168/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 169/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 170/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 171/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 172/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 173/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 174/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 175/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 176/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 177/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 178/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 179/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 180/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0100
# Epoch 181/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 182/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 183/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 184/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 185/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 186/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 187/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0100
# Epoch 188/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 189/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 190/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 191/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0100
# Epoch 192/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0101
# Epoch 193/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 194/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 195/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 196/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0101
# Epoch 197/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 198/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 199/200
# 2554/2554 [==============================] - 7s 3ms/sample - loss: 0.0100
# Epoch 200/200
# 2554/2554 [==============================] - 6s 3ms/sample - loss: 0.0100

# %% [markdown]
# ## Make Predictions and Evaluate your model

# %%
import math
from sklearn.metrics import mean_squared_error

trainPredict = model.predict(X_train, batch_size=batch_size)

testPredict = model.predict(X_test, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 2.61 RMSE
# Test Score: 2.44 RMSE

# %% [markdown]
# ## Plot the results

# %%
trainPredictPlot = np.empty_like(scaled)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(scaled), :] = testPredict
# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(scaled))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
